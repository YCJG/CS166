# %%
import networkx

# %%
print(networkx.__version__)
# Out:
# 2.4

# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
G4 = nx.complete_graph(4)
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
nx.draw_circular(G4, ax=ax)

# %%
G5 = nx.complete_graph(5)
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
nx.draw_circular(G5, ax=ax)

# %%
from networkx.algorithms import bipartite
B = nx.Graph()
# Add nodes with the node attribute "bipartite"
B.add_nodes_from([1, 2, 3, 4], bipartite=0)
B.add_nodes_from(["a", "b", "c"], bipartite=1)
# Add edges only between nodes of opposite node sets
B.add_edges_from([(1, "a"), (1, "b"), (2, "b"), (2, "c"), (3, "c"), (4, "a")])

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
nx.draw_circular(B, ax=ax)

# %%
hypercube = nx.hypercube_graph(4)
nx.draw_networkx(hypercube)

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
nx.draw_circular(hypercube, ax=ax)

# %%
ladder = nx.ladder_graph(5)
nx.draw_networkx(ladder)

# %%
# barbell(n, m)
# n is nodes
# m is node bridge
barbell = nx.barbell_graph(20, 1)
#fig, ax = plt.subplots(1, 1, figsize=(6, 6))
#nx.draw_circular(barbell, ax=ax)
nx.draw_networkx(barbell)

# %%
wheel = nx.wheel_graph(100)
nx.draw_networkx(wheel)

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
nx.draw_circular(wheel, ax=ax)
